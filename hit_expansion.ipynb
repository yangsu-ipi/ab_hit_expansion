# %%
from utils.notebook_hit_expansion import HitExpansionUI
hit_expansion = HitExpansionUI(
    input_root = "/alphafold/combio/NGS", 
    output_root = "/home/yang.su/ngs_hit_expansion", 
)
hit_expansion.setup()

# %%
hit_expansion.run()
