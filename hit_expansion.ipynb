# %%
from utils.notebook_hit_expansion import HitExpansionUI
hit_expansion = HitExpansionUI()
hit_expansion.setup()

# %%
hit_expansion.run()
# Out:
# Output location: /home/yang.su/ngs_hit_expansion/alphafold/combio/NGS/NGS_20260120_Miseq108/results/hADGRL4_20-431_MBP-AH_Block198_clones_hit_expansion
# Dropped 4543 unusable leads
# 7142 usable leads
# VL scaffolds: ['K1-39', 'K3-15', 'K3-20', 'K4-1']
# Train set: 5713 leads, 2262 enriched
# Test set: 1429 leads, 570 enriched
# Train AUC: 0.91
# Test AUC: 0.91
# Validation set: 7142 leads, 2679 enriched
# Validation AUC: 0.91
# count hADGRL4_20-431_MBP-AH__Block198__Round7__F_P__4nM_Block198.csv Spearman: 0.40
# Top k-mers
# ----------
# GAF    7.383776
# YPP    7.202334
# RN     7.176783
# KI     6.789469
# ID     6.773388
# RDE    6.591995
# RAR    6.077953
# KGR    6.035128
# GWP    5.720582
# C      5.557858
# RLW    5.555200
# AQW    5.547759
# RGV    5.277371
# IS     4.975782
# YRV    4.856856
# QW     4.688480
# FD    -4.421015
# WG    -4.460238
# PT    -4.722810
# DV    -4.832831
# ARP   -4.893516
# RWY   -4.916651
# RGI   -5.013108
# IG    -5.146098
# RLG   -5.365566
# ...
